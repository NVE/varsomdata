# %% [markdown]
# # Using getobservations.py
#
# This is an example of how varsomdata/getobservations.py may be used to get observations from the regObs webapi - http://api.nve.no/doc/regobs-webapi/
#
# It takes time to make requests. Progress can be followed in the log files.

# %%
# Make sure varsomdata is in your Pythonpath
import sys, os
sys.path.append(os.path.dirname(os.path.abspath(os.getcwd())))
#print(sys.executable, "\n", sys.path)

import datetime as dt
from pprint import pprint

# %%
from varsomdata import getobservations as go

__author__ = 'raek'

# %% [markdown]
# One observation with a given ID may

# %%
one_obs = go.get_data(reg_ids=130548)
pprint(one_obs)
# Out:
# [{'AttachmentSummaries': [{'RegistrationName': 'Bilde',
#                            'RegistrationTID': 12,
#                            'Summaries': [{'Header': 'Kommentar',
#                                           'Kind': 1,
#                                           'KindType': 'Text',
#                                           'Value': 'Lavt skydekke . Regn fra '
#                                                    '0-1200/1300. Snø over '
#                                                    'det.'},
#                                          {'Header': 'Av',
#                                           'Kind': 1,
#                                           'KindType': 'Text',
#                                           'Value': 'Snødekke'},
#                                          {'Header': 'Copyright',
#                                           'Kind': 1,
#                                           'KindType': 'Text',
#                                           'Value': 'Siggen@obskorps'},
#                                          {'Header': 'Kommentar',
#                                           'Kind': 1,
#                                           'KindType': 'Text',
#                                           'Value': 'Lavt skydekke . Regn fra '
#                                                    '0-1200/1300. Snø over '
#                                                    'det.'}]}],
#   'Attachments': [{'Aspect': None,
#                    'AttachmentFileName': '58712.jpg',
#                    'AttachmentMimeType': 'image/jpeg',
#                    'Comment': 'Lavt skydekke . Regn fra 0-1200/1300. Snø over '
#                               'det.',
#                    'Copyright': 'Siggen@obskorps',
#                    'GeoHazardName': 'Snø',
#                    'GeoHazardTID': 10,
#                    'IsMainAttachment': False,
#                    'Photographer': None,
#                    'PictureID': 58712,
#                    'RegID': 130548,
#                    'RegistrationName': 'Snødekke',
#                    'RegistrationTID': 22}],
#   'AvalancheActivityObs': [],
#   'AvalancheActivityObs2': [],
#   'AvalancheDangerObs': [],
#   'AvalancheEvalProblem': [],
#   'AvalancheEvalProblem2': [],
#   'AvalancheEvaluation': None,
#   'AvalancheEvaluation2': None,
#   'AvalancheEvaluation3': None,
#   'AvalancheObs': None,
#   'CompressionTest': [],
#   'DamageObs': [],
#   'DangerObs': [],
#   'DtChangeTime': '2017-09-20T15:43:44+00:00',
#   'DtObsTime': '2017-09-20T17:38:00+02:00',
#   'DtRegTime': '2017-09-20T15:43:44+00:00',
#   'GeneralObservation': None,
#   'GeoHazardName': 'Snø',
#   'GeoHazardTID': 10,
#   'IceCoverObs': None,
#   'IceThickness': None,
#   'Incident': None,
#   'LandSlideObs': None,
#   'LangKey': 1,
#   'ObsLocation': {'Comment': None,
#                   'CountryId': 578,
#                   'CountryName': 'Norge',
#                   'ForecastRegionName': 'Indre Sogn',
#                   'ForecastRegionTID': 3029,
#                   'Height': 626,
#                   'Latitude': 61.6872246224,
#                   'LocationDescription': None,
#                   'LocationName': None,
#                   'Longitude': 7.1987894707,
#                   'MunicipalName': 'Luster',
#                   'MunicipalNo': '4644',
#                   'ObsLocationID': 61271,
#                   'Title': 'Indre Sogn / Luster',
#                   'UTMEast': 87915,
#                   'UTMNorth': 6864091,
#                   'UTMSourceName': 'Ukjent',
#                   'UTMSourceTID': 35,
#                   'UTMZone': 33,
#                   'Uncertainty': 0},
#   'Observer': {'CompetenceLevelName': '****',
#                'CompetenceLevelTID': 130,
#                'NickName': 'Siggen@obskorps',
#                'ObserverGUID': '49f5a0f6-69bf-49c7-9206-6de9fd91c043',
#                'ObserverGroupID': 0,
#                'ObserverGroupName': None,
#                'ObserverID': 325,
#                'ObserverName': 'Siggen@obskorps'},
#   'RegID': 130548,
#   'SnowCoverObs': None,
#   'SnowProfile': None,
#   'SnowProfile2': None,
#   'SnowSurfaceObservation': {'Comment': 'Snøfall ned til ca 1200-1300moh, regn '
#                                         'under det. Nysnøen lander på bar '
#                                         'bakke. Ikke vært i høyden.',
#                              'FootPenetration': None,
#                              'HeightLimitLayeredSnow': None,
#                              'NewSnowDepth24': None,
#                              'NewSnowLine': 1200,
#                              'SnowDepth': None,
#                              'SnowDriftName': 'Ikke observert',
#                              'SnowDriftTID': 0,
#                              'SnowLine': 1200,
#                              'SnowSurfaceName': 'Ikke observert',
#                              'SnowSurfaceTID': 0,
#                              'SnowWindDepth24': None,
#                              'SurfaceRougnessName': 'Ikke observert',
#                              'SurfaceRougnessTID': 0,
#                              'SurfaceWaterContentName': 'Ikke observert',
#                              'SurfaceWaterContentTID': 0},
#   'SourceName': 'Ikke gitt',
#   'SourceTID': 0,
#   'Summaries': [{'RegistrationName': 'Vær',
#                  'RegistrationTID': 21,
#                  'Summaries': [{'Header': 'Nedbørstype',
#                                 'Kind': 1,
#                                 'KindType': 'Text',
#                                 'Value': 'Ikke nedbør'},
#                                {'Header': 'Temperatur',
#                                 'Kind': 1,
#                                 'KindType': 'Text',
#                                 'Value': '6 °C'},
#                                {'Header': 'Vind',
#                                 'Kind': 1,
#                                 'KindType': 'Text',
#                                 'Value': '0 m/s'},
#                                {'Header': 'Skydekke',
#                                 'Kind': 1,
#                                 'KindType': 'Text',
#                                 'Value': '100% skyer'},
#                                {'Header': 'Kommentar',
#                                 'Kind': 1,
#                                 'KindType': 'Text',
#                                 'Value': 'Nå kl 17.30 på ca 200moh. Opphold '
#                                          'nå. Kraftig regn i morgentimen, før '
#                                          'solen sto opp. Perioder med regn '
#                                          'midt på dagen, opphold skyet nå.'}]},
#                 {'RegistrationName': 'Snødekke',
#                  'RegistrationTID': 22,
#                  'Summaries': [{'Header': 'Snøgrenser',
#                                 'Kind': 1,
#                                 'KindType': 'Text',
#                                 'Value': 'Nysnøgrense på 1200 moh. Snøgrense '
#                                          'på 1200 moh'},
#                                {'Header': 'Kommentar',
#                                 'Kind': 1,
#                                 'KindType': 'Text',
#                                 'Value': 'Snøfall ned til ca 1200-1300moh, '
#                                          'regn under det. Nysnøen lander på '
#                                          'bar bakke. Ikke vært i høyden.'}]}],
#   'WaterLevel': None,
#   'WaterLevel2': None,
#   'WeatherObservation': {'AirTemperature': 6.0,
#                          'CloudCover': 100,
#                          'Comment': 'Nå kl 17.30 på ca 200moh. Opphold nå. '
#                                     'Kraftig regn i morgentimen, før solen sto '
#                                     'opp. Perioder med regn midt på dagen, '
#                                     'opphold skyet nå.',
#                          'PrecipitationName': 'Ikke nedbør',
#                          'PrecipitationTID': 1,
#                          'WindDirection': None,
#                          'WindDirectionName': None,
#                          'WindSpeed': 0.0}}]

# %% [markdown]
# If multiple id's wil be used, give them as list. Result may be returned as a list of forms (default) or nested, i.e. all forms are listed under their respective observations.

# %%
two_obs = go.get_data(reg_ids=[130548, 130328])
pprint(two_obs)
# Out:
# [{'AttachmentSummaries': [{'RegistrationName': 'Bilde',
#                            'RegistrationTID': 12,
#                            'Summaries': [{'Header': 'Kommentar',
#                                           'Kind': 1,
#                                           'KindType': 'Text',
#                                           'Value': 'Lavt skydekke . Regn fra '
#                                                    '0-1200/1300. Snø over '
#                                                    'det.'},
#                                          {'Header': 'Av',
#                                           'Kind': 1,
#                                           'KindType': 'Text',
#                                           'Value': 'Snødekke'},
#                                          {'Header': 'Copyright',
#                                           'Kind': 1,
#                                           'KindType': 'Text',
#                                           'Value': 'Siggen@obskorps'},
#                                          {'Header': 'Kommentar',
#                                           'Kind': 1,
#                                           'KindType': 'Text',
#                                           'Value': 'Lavt skydekke . Regn fra '
#                                                    '0-1200/1300. Snø over '
#                                                    'det.'}]}],
#   'Attachments': [{'Aspect': None,
#                    'AttachmentFileName': '58712.jpg',
#                    'AttachmentMimeType': 'image/jpeg',
#                    'Comment': 'Lavt skydekke . Regn fra 0-1200/1300. Snø over '
#                               'det.',
#                    'Copyright': 'Siggen@obskorps',
#                    'GeoHazardName': 'Snø',
#                    'GeoHazardTID': 10,
#                    'IsMainAttachment': False,
#                    'Photographer': None,
#                    'PictureID': 58712,
#                    'RegID': 130548,
#                    'RegistrationName': 'Snødekke',
#                    'RegistrationTID': 22}],
#   'AvalancheActivityObs': [],
#   'AvalancheActivityObs2': [],
#   'AvalancheDangerObs': [],
#   'AvalancheEvalProblem': [],
#   'AvalancheEvalProblem2': [],
#   'AvalancheEvaluation': None,
#   'AvalancheEvaluation2': None,
#   'AvalancheEvaluation3': None,
#   'AvalancheObs': None,
#   'CompressionTest': [],
#   'DamageObs': [],
#   'DangerObs': [],
#   'DtChangeTime': '2017-09-20T15:43:44+00:00',
#   'DtObsTime': '2017-09-20T17:38:00+02:00',
#   'DtRegTime': '2017-09-20T15:43:44+00:00',
#   'GeneralObservation': None,
#   'GeoHazardName': 'Snø',
#   'GeoHazardTID': 10,
#   'IceCoverObs': None,
#   'IceThickness': None,
#   'Incident': None,
#   'LandSlideObs': None,
#   'LangKey': 1,
#   'ObsLocation': {'Comment': None,
#                   'CountryId': 578,
#                   'CountryName': 'Norge',
#                   'ForecastRegionName': 'Indre Sogn',
#                   'ForecastRegionTID': 3029,
#                   'Height': 626,
#                   'Latitude': 61.6872246224,
#                   'LocationDescription': None,
#                   'LocationName': None,
#                   'Longitude': 7.1987894707,
#                   'MunicipalName': 'Luster',
#                   'MunicipalNo': '4644',
#                   'ObsLocationID': 61271,
#                   'Title': 'Indre Sogn / Luster',
#                   'UTMEast': 87915,
#                   'UTMNorth': 6864091,
#                   'UTMSourceName': 'Ukjent',
#                   'UTMSourceTID': 35,
#                   'UTMZone': 33,
#                   'Uncertainty': 0},
#   'Observer': {'CompetenceLevelName': '****',
#                'CompetenceLevelTID': 130,
#                'NickName': 'Siggen@obskorps',
#                'ObserverGUID': '49f5a0f6-69bf-49c7-9206-6de9fd91c043',
#                'ObserverGroupID': 0,
#                'ObserverGroupName': None,
#                'ObserverID': 325,
#                'ObserverName': 'Siggen@obskorps'},
#   'RegID': 130548,
#   'SnowCoverObs': None,
#   'SnowProfile': None,
#   'SnowProfile2': None,
#   'SnowSurfaceObservation': {'Comment': 'Snøfall ned til ca 1200-1300moh, regn '
#                                         'under det. Nysnøen lander på bar '
#                                         'bakke. Ikke vært i høyden.',
#                              'FootPenetration': None,
#                              'HeightLimitLayeredSnow': None,
#                              'NewSnowDepth24': None,
#                              'NewSnowLine': 1200,
#                              'SnowDepth': None,
#                              'SnowDriftName': 'Ikke observert',
#                              'SnowDriftTID': 0,
#                              'SnowLine': 1200,
#                              'SnowSurfaceName': 'Ikke observert',
#                              'SnowSurfaceTID': 0,
#                              'SnowWindDepth24': None,
#                              'SurfaceRougnessName': 'Ikke observert',
#                              'SurfaceRougnessTID': 0,
#                              'SurfaceWaterContentName': 'Ikke observert',
#                              'SurfaceWaterContentTID': 0},
#   'SourceName': 'Ikke gitt',
#   'SourceTID': 0,
#   'Summaries': [{'RegistrationName': 'Vær',
#                  'RegistrationTID': 21,
#                  'Summaries': [{'Header': 'Nedbørstype',
#                                 'Kind': 1,
#                                 'KindType': 'Text',
#                                 'Value': 'Ikke nedbør'},
#                                {'Header': 'Temperatur',
#                                 'Kind': 1,
#                                 'KindType': 'Text',
#                                 'Value': '6 °C'},
#                                {'Header': 'Vind',
#                                 'Kind': 1,
#                                 'KindType': 'Text',
#                                 'Value': '0 m/s'},
#                                {'Header': 'Skydekke',
#                                 'Kind': 1,
#                                 'KindType': 'Text',
#                                 'Value': '100% skyer'},
#                                {'Header': 'Kommentar',
#                                 'Kind': 1,
#                                 'KindType': 'Text',
#                                 'Value': 'Nå kl 17.30 på ca 200moh. Opphold '
#                                          'nå. Kraftig regn i morgentimen, før '
#                                          'solen sto opp. Perioder med regn '
#                                          'midt på dagen, opphold skyet nå.'}]},
#                 {'RegistrationName': 'Snødekke',
#                  'RegistrationTID': 22,
#                  'Summaries': [{'Header': 'Snøgrenser',
#                                 'Kind': 1,
#                                 'KindType': 'Text',
#                                 'Value': 'Nysnøgrense på 1200 moh. Snøgrense '
#                                          'på 1200 moh'},
#                                {'Header': 'Kommentar',
#                                 'Kind': 1,
#                                 'KindType': 'Text',
#                                 'Value': 'Snøfall ned til ca 1200-1300moh, '
#                                          'regn under det. Nysnøen lander på '
#                                          'bar bakke. Ikke vært i høyden.'}]}],
#   'WaterLevel': None,
#   'WaterLevel2': None,
#   'WeatherObservation': {'AirTemperature': 6.0,
#                          'CloudCover': 100,
#                          'Comment': 'Nå kl 17.30 på ca 200moh. Opphold nå. '
#                                     'Kraftig regn i morgentimen, før solen sto '
#                                     'opp. Perioder med regn midt på dagen, '
#                                     'opphold skyet nå.',
#                          'PrecipitationName': 'Ikke nedbør',
#                          'PrecipitationTID': 1,
#                          'WindDirection': None,
#                          'WindDirectionName': None,
#                          'WindSpeed': 0.0}},
#  {'AttachmentSummaries': [{'RegistrationName': 'Bilde',
#                            'RegistrationTID': 12,
#                            'Summaries': [{'Header': 'Kommentar',
#                                           'Kind': 1,
#                                           'KindType': 'Text',
#                                           'Value': 'Grått'},
#                                          {'Header': 'Av',
#                                           'Kind': 1,
#                                           'KindType': 'Text',
#                                           'Value': 'Vær'},
#                                          {'Header': 'Copyright',
#                                           'Kind': 1,
#                                           'KindType': 'Text',
#                                           'Value': 'Ingljo'},
#                                          {'Header': 'Kommentar',
#                                           'Kind': 1,
#                                           'KindType': 'Text',
#                                           'Value': 'Grått'}]}],
#   'Attachments': [{'Aspect': None,
#                    'AttachmentFileName': '58312.jpg',
#                    'AttachmentMimeType': 'image/jpeg',
#                    'Comment': 'Grått',
#                    'Copyright': 'Ingljo',
#                    'GeoHazardName': 'Snø',
#                    'GeoHazardTID': 10,
#                    'IsMainAttachment': False,
#                    'Photographer': None,
#                    'PictureID': 58312,
#                    'RegID': 130328,
#                    'RegistrationName': 'Vær',
#                    'RegistrationTID': 21}],
#   'AvalancheActivityObs': [],
#   'AvalancheActivityObs2': [],
#   'AvalancheDangerObs': [],
#   'AvalancheEvalProblem': [],
#   'AvalancheEvalProblem2': [],
#   'AvalancheEvaluation': None,
#   'AvalancheEvaluation2': None,
#   'AvalancheEvaluation3': None,
#   'AvalancheObs': None,
#   'CompressionTest': [],
#   'DamageObs': [],
#   'DangerObs': [],
#   'DtChangeTime': '2017-09-04T17:10:42+00:00',
#   'DtObsTime': '2017-09-04T19:07:00+02:00',
#   'DtRegTime': '2017-09-04T17:10:42+00:00',
#   'GeneralObservation': None,
#   'GeoHazardName': 'Snø',
#   'GeoHazardTID': 10,
#   'IceCoverObs': None,
#   'IceThickness': None,
#   'Incident': None,
#   'LandSlideObs': None,
#   'LangKey': 1,
#   'ObsLocation': {'Comment': None,
#                   'CountryId': 578,
#                   'CountryName': 'Norge',
#                   'ForecastRegionName': 'Oslo',
#                   'ForecastRegionTID': 3045,
#                   'Height': 30,
#                   'Latitude': 59.9274232923,
#                   'LocationDescription': None,
#                   'LocationName': None,
#                   'Longitude': 10.7504060168,
#                   'MunicipalName': 'OSLO',
#                   'MunicipalNo': '0301',
#                   'ObsLocationID': 61066,
#                   'Title': 'Oslo / OSLO',
#                   'UTMEast': 262557,
#                   'UTMNorth': 6650954,
#                   'UTMSourceName': 'Ukjent',
#                   'UTMSourceTID': 35,
#                   'UTMZone': 33,
#                   'Uncertainty': 0},
#   'Observer': {'CompetenceLevelName': 'Ukjent',
#                'CompetenceLevelTID': 0,
#                'NickName': 'Ingljo',
#                'ObserverGUID': 'acb6b644-9721-47d0-b0d7-74596bb5a37e',
#                'ObserverGroupID': 0,
#                'ObserverGroupName': None,
#                'ObserverID': 3651,
#                'ObserverName': 'Ingljo'},
#   'RegID': 130328,
#   'SnowCoverObs': None,
#   'SnowProfile': None,
#   'SnowProfile2': None,
#   'SnowSurfaceObservation': None,
#   'SourceName': 'Ikke gitt',
#   'SourceTID': 0,
#   'Summaries': [{'RegistrationName': 'Vær',
#                  'RegistrationTID': 21,
#                  'Summaries': [{'Header': 'Nedbørstype',
#                                 'Kind': 1,
#                                 'KindType': 'Text',
#                                 'Value': 'Yr'},
#                                {'Header': 'Temperatur',
#                                 'Kind': 1,
#                                 'KindType': 'Text',
#                                 'Value': '11 °C'},
#                                {'Header': 'Skydekke',
#                                 'Kind': 1,
#                                 'KindType': 'Text',
#                                 'Value': '100% skyer'}]}],
#   'WaterLevel': None,
#   'WaterLevel2': None,
#   'WeatherObservation': {'AirTemperature': 11.0,
#                          'CloudCover': 100,
#                          'Comment': '',
#                          'PrecipitationName': 'Yr',
#                          'PrecipitationTID': 2,
#                          'WindDirection': None,
#                          'WindDirectionName': None,
#                          'WindSpeed': None}}]

# %% [markdown]
# A request may specify a time period and specific geohazards.
# Snow is 10 and ice is 70. Water is 60. Dirt is [20, 30, 40]

# %%
all_data_snow = go.get_data('2016-12-30', '2017-01-01', geohazard_tids=10)
ice_data = go.get_data(from_date='2016-10-01', to_date='2016-11-01', geohazard_tids=70)

# %% [markdown]
# The data may be returned as a list of classes, as opposed to the default return in get_data which are dictionaries raw as given on regObs webapi.

# %%
data_as_classes = go.get_all_observations('2018-05-01', '2018-08-01')

# %% [markdown]
# We may get observation forms directly. Note, from and to date are first and may also be given as positional arguments, even though Is recommend keyword arguments.

# %%
land_slides = go.get_land_slide_obs('2018-01-01', '2018-02-01')
incident = go.get_incident('2012-03-01', '2012-03-10')
ice_thicks = go.get_ice_thickness('2018-01-20', '2018-02-10')
snow_surface = go.get_snow_surface_observation('2018-01-28', '2018-02-01')
problems = go.get_avalanche_problem_2('2017-03-01', '2017-03-10')
